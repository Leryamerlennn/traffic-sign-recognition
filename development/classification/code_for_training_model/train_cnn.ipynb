# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_dir = "/kaggle/input/cvprojectdatasettest/myData"
classes = sorted(
    [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))],
    key=lambda x: int(x) if x.isdigit() else x
)
img_size = (32, 32)
batch_size = 64

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,        # 80/20 train/val
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_gen = datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    classes=classes,
)

val_gen = datagen.flow_from_directory(
    train_dir,
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    classes=classes,
)
# Out:
# 2025-11-18 22:10:45.368375: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763503845.579351      39 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763503845.635704      39 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 132128 images belonging to 44 classes.
# Found 33000 images belonging to 44 classes.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

num_classes = 44
img_size = (32, 32)

model = models.Sequential([
    layers.Input(shape=(*img_size, 3)),          # RGB
    layers.Conv2D(32, 3, activation='relu'),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Conv2D(64, 3, activation='relu'),
    layers.Conv2D(64, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# I0000 00:00:1763503914.910207      39 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 28, 28, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 12, 12, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       409,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 44)             │        11,308 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 486,732 (1.86 MB)
#  Trainable params: 486,732 (1.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

ckpt_path = "/kaggle/working/traffic_signs_cnn.keras"

cbs = [
    EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-5, verbose=1),
    ModelCheckpoint(ckpt_path, monitor='val_accuracy', save_best_only=True, verbose=1)
]

# %%
history = model.fit(
    train_gen,
    epochs=10,
    validation_data=val_gen,
    callbacks=cbs,
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763503919.652468     113 service.cc:148] XLA service 0x7a92c0004540 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763503919.653516     113 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1763503920.026459     113 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    1/2065 ━━━━━━━━━━━━━━━━━━━━ 3:50:02 7s/step - accuracy: 0.0156 - loss: 3.7866
# I0000 00:00:1763503923.386307     113 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.3910 - loss: 2.1855
# Epoch 1: val_accuracy improved from -inf to 0.91742, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 498s 238ms/step - accuracy: 0.3911 - loss: 2.1850 - val_accuracy: 0.9174 - val_loss: 0.2993 - learning_rate: 0.0010
# Epoch 2/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8704 - loss: 0.4156
# Epoch 2: val_accuracy improved from 0.91742 to 0.97358, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 211s 102ms/step - accuracy: 0.8704 - loss: 0.4156 - val_accuracy: 0.9736 - val_loss: 0.1054 - learning_rate: 0.0010
# Epoch 3/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9274 - loss: 0.2388
# Epoch 3: val_accuracy improved from 0.97358 to 0.97894, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 213s 103ms/step - accuracy: 0.9274 - loss: 0.2388 - val_accuracy: 0.9789 - val_loss: 0.0757 - learning_rate: 0.0010
# Epoch 4/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9465 - loss: 0.1766
# Epoch 4: val_accuracy improved from 0.97894 to 0.98585, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 212s 103ms/step - accuracy: 0.9465 - loss: 0.1766 - val_accuracy: 0.9858 - val_loss: 0.0553 - learning_rate: 0.0010
# Epoch 5/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9559 - loss: 0.1465
# Epoch 5: val_accuracy improved from 0.98585 to 0.98642, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 216s 105ms/step - accuracy: 0.9559 - loss: 0.1465 - val_accuracy: 0.9864 - val_loss: 0.0498 - learning_rate: 0.0010
# Epoch 6/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9632 - loss: 0.1231
# Epoch 6: val_accuracy improved from 0.98642 to 0.98782, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 213s 103ms/step - accuracy: 0.9632 - loss: 0.1231 - val_accuracy: 0.9878 - val_loss: 0.0449 - learning_rate: 0.0010
# Epoch 7/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9640 - loss: 0.1181
# Epoch 7: val_accuracy improved from 0.98782 to 0.99061, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 212s 102ms/step - accuracy: 0.9640 - loss: 0.1181 - val_accuracy: 0.9906 - val_loss: 0.0396 - learning_rate: 0.0010
# Epoch 8/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9687 - loss: 0.1061
# Epoch 8: val_accuracy did not improve from 0.99061
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 213s 103ms/step - accuracy: 0.9687 - loss: 0.1061 - val_accuracy: 0.9897 - val_loss: 0.0433 - learning_rate: 0.0010
# Epoch 9/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9703 - loss: 0.1001
# Epoch 9: val_accuracy did not improve from 0.99061
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 213s 103ms/step - accuracy: 0.9703 - loss: 0.1000 - val_accuracy: 0.9903 - val_loss: 0.0385 - learning_rate: 0.0010
# Epoch 10/10
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9714 - loss: 0.0977
# Epoch 10: val_accuracy improved from 0.99061 to 0.99188, saving model to /kaggle/working/traffic_signs_cnn.keras
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 216s 105ms/step - accuracy: 0.9714 - loss: 0.0977 - val_accuracy: 0.9919 - val_loss: 0.0307 - learning_rate: 0.0010

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('Accuracy'); plt.xlabel('epoch'); plt.ylabel('acc'); plt.legend(); plt.show()

plt.figure(figsize=(6,4))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Loss'); plt.xlabel('epoch'); plt.ylabel('loss'); plt.legend(); plt.show()

# %%
val_loss, val_acc = model.evaluate(val_gen, verbose=0)
print(f"Val accuracy: {val_acc*100:.2f}%")
model.save("/kaggle/working/traffic_signs_cnn_final.keras")
# Out:
# Val accuracy: 99.08%

# %%
from IPython.display import FileLink
FileLink('/kaggle/working/traffic_signs_cnn_final.keras')
# Out:
# /kaggle/working/traffic_signs_cnn_final.keras

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
